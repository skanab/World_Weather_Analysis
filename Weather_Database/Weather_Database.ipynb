# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime
from config import weather_api_key
import time
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]['description']
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
#        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Description": city_description,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
#                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | sao joao da barra
# Processing Record 4 of Set 1 | lavrentiya
# Processing Record 5 of Set 1 | manthani
# Processing Record 6 of Set 1 | marsh harbour
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 1 | rosarito
# Processing Record 12 of Set 1 | tula
# Processing Record 13 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 1 | awjilah
# Processing Record 17 of Set 1 | kahului
# Processing Record 18 of Set 1 | port elizabeth
# Processing Record 19 of Set 1 | saint-philippe
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | namatanai
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | severo-kurilsk
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | atbasar
# Processing Record 27 of Set 1 | lata
# Processing Record 28 of Set 1 | poum
# Processing Record 29 of Set 1 | rawson
# Processing Record 30 of Set 1 | isangel
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | east london
# Processing Record 33 of Set 1 | arman
# Processing Record 34 of Set 1 | atikokan
# Processing Record 35 of Set 1 | nioro
# Processing Record 36 of Set 1 | diplo
# Processing Record 37 of Set 1 | revda
# Processing Record 38 of Set 1 | chisinau
# Processing Record 39 of Set 1 | zaysan
# Processing Record 40 of Set 1 | iqaluit
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | naze
# Processing Record 43 of Set 1 | aklavik
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | bamiantong
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | san cristobal
# Processing Record 48 of Set 1 | tasiilaq
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | rikitea
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | ciudad bolivar
# Processing Record 4 of Set 2 | viedma
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | mataura
# Processing Record 7 of Set 2 | nikolskoye
# Processing Record 8 of Set 2 | ridgecrest
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | mayna
# Processing Record 11 of Set 2 | boyolangu
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | champerico
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 2 | constitucion
# Processing Record 16 of Set 2 | maragogi
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | luganville
# Processing Record 19 of Set 2 | salalah
# Processing Record 20 of Set 2 | bethel
# Processing Record 21 of Set 2 | dalneye konstantinovo
# City not found. Skipping...
# Processing Record 22 of Set 2 | eyl
# Processing Record 23 of Set 2 | san quintin
# Processing Record 24 of Set 2 | bunda
# Processing Record 25 of Set 2 | talnakh
# Processing Record 26 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | chokurdakh
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | a
# City not found. Skipping...
# Processing Record 32 of Set 2 | alice springs
# Processing Record 33 of Set 2 | mattru
# Processing Record 34 of Set 2 | norrtalje
# Processing Record 35 of Set 2 | jesus
# Processing Record 36 of Set 2 | byron bay
# Processing Record 37 of Set 2 | san miguel
# Processing Record 38 of Set 2 | thinadhoo
# Processing Record 39 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | fraserburgh
# Processing Record 42 of Set 2 | lorengau
# Processing Record 43 of Set 2 | vestmannaeyjar
# Processing Record 44 of Set 2 | tual
# Processing Record 45 of Set 2 | hecun
# Processing Record 46 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 2 | ribeira grande
# Processing Record 48 of Set 2 | katsuura
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | pisco
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | aldan
# Processing Record 3 of Set 3 | provideniya
# Processing Record 4 of Set 3 | cayenne
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | ushuaia
# Processing Record 7 of Set 3 | flin flon
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | ponta do sol
# Processing Record 10 of Set 3 | kutum
# Processing Record 11 of Set 3 | labuhan
# Processing Record 12 of Set 3 | gat
# Processing Record 13 of Set 3 | avera
# Processing Record 14 of Set 3 | grand baie
# Processing Record 15 of Set 3 | vilyuysk
# Processing Record 16 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 3 | tarakan
# Processing Record 19 of Set 3 | port alfred
# Processing Record 20 of Set 3 | nuuk
# Processing Record 21 of Set 3 | kortkeros
# Processing Record 22 of Set 3 | challapata
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | novopokrovka
# Processing Record 26 of Set 3 | bilibino
# Processing Record 27 of Set 3 | atka
# City not found. Skipping...
# Processing Record 28 of Set 3 | loei
# Processing Record 29 of Set 3 | inhambane
# Processing Record 30 of Set 3 | kyra
# Processing Record 31 of Set 3 | nome
# Processing Record 32 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 3 | college
# Processing Record 34 of Set 3 | marzuq
# Processing Record 35 of Set 3 | ucluelet
# Processing Record 36 of Set 3 | pangai
# Processing Record 37 of Set 3 | bluff
# Processing Record 38 of Set 3 | jamestown
# Processing Record 39 of Set 3 | kodiak
# Processing Record 40 of Set 3 | saint george
# Processing Record 41 of Set 3 | beni mazar
# Processing Record 42 of Set 3 | omboue
# Processing Record 43 of Set 3 | santa maria
# Processing Record 44 of Set 3 | clyde river
# Processing Record 45 of Set 3 | ubud
# Processing Record 46 of Set 3 | karratha
# Processing Record 47 of Set 3 | norman wells
# Processing Record 48 of Set 3 | torbay
# Processing Record 49 of Set 3 | seoul
# Processing Record 50 of Set 3 | kaitangata
# Processing Record 1 of Set 4 | ayan
# Processing Record 2 of Set 4 | cockburn town
# Processing Record 3 of Set 4 | yaan
# Processing Record 4 of Set 4 | hithadhoo
# Processing Record 5 of Set 4 | pantelimon
# Processing Record 6 of Set 4 | sao felix do xingu
# Processing Record 7 of Set 4 | pangnirtung
# Processing Record 8 of Set 4 | samarai
# Processing Record 9 of Set 4 | grindavik
# Processing Record 10 of Set 4 | mazatlan
# Processing Record 11 of Set 4 | tomatlan
# Processing Record 12 of Set 4 | narsaq
# Processing Record 13 of Set 4 | vardo
# Processing Record 14 of Set 4 | te anau
# Processing Record 15 of Set 4 | riyadh
# Processing Record 16 of Set 4 | lewistown
# Processing Record 17 of Set 4 | komsomolskiy
# Processing Record 18 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 4 | terrace
# Processing Record 20 of Set 4 | marsabit
# Processing Record 21 of Set 4 | hinton
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | burica
# City not found. Skipping...
# Processing Record 24 of Set 4 | puerto ayora
# Processing Record 25 of Set 4 | puerto escondido
# Processing Record 26 of Set 4 | hofn
# Processing Record 27 of Set 4 | kirkwall
# Processing Record 28 of Set 4 | fairbanks
# Processing Record 29 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 4 | shirokiy
# Processing Record 31 of Set 4 | dunedin
# Processing Record 32 of Set 4 | hualmay
# Processing Record 33 of Set 4 | la ronge
# Processing Record 34 of Set 4 | denpasar
# Processing Record 35 of Set 4 | yellowknife
# Processing Record 36 of Set 4 | saint anthony
# Processing Record 37 of Set 4 | port blair
# Processing Record 38 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 39 of Set 4 | esperance
# Processing Record 40 of Set 4 | san patricio
# Processing Record 41 of Set 4 | ozernovskiy
# Processing Record 42 of Set 4 | esfarayen
# Processing Record 43 of Set 4 | saint-marc
# Processing Record 44 of Set 4 | haines junction
# Processing Record 45 of Set 4 | victoria
# Processing Record 46 of Set 4 | huarmey
# Processing Record 47 of Set 4 | mizan teferi
# Processing Record 48 of Set 4 | roald
# Processing Record 49 of Set 4 | aleksin
# Processing Record 50 of Set 4 | srednekolymsk
# Processing Record 1 of Set 5 | templin
# Processing Record 2 of Set 5 | vila franca do campo
# Processing Record 3 of Set 5 | tessalit
# Processing Record 4 of Set 5 | namibe
# Processing Record 5 of Set 5 | oda
# Processing Record 6 of Set 5 | ahipara
# Processing Record 7 of Set 5 | ewa beach
# Processing Record 8 of Set 5 | hasaki
# Processing Record 9 of Set 5 | klaksvik
# Processing Record 10 of Set 5 | kismayo
# Processing Record 11 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 5 | madimba
# Processing Record 13 of Set 5 | massaguet
# Processing Record 14 of Set 5 | saint-georges
# Processing Record 15 of Set 5 | naryan-mar
# Processing Record 16 of Set 5 | thompson
# Processing Record 17 of Set 5 | pulaski
# Processing Record 18 of Set 5 | erzin
# Processing Record 19 of Set 5 | sargur
# Processing Record 20 of Set 5 | lungi
# Processing Record 21 of Set 5 | tiksi
# Processing Record 22 of Set 5 | high prairie
# Processing Record 23 of Set 5 | estevan
# Processing Record 24 of Set 5 | paita
# Processing Record 25 of Set 5 | cidreira
# Processing Record 26 of Set 5 | marystown
# Processing Record 27 of Set 5 | umm lajj
# Processing Record 28 of Set 5 | itupiranga
# Processing Record 29 of Set 5 | hatillo
# Processing Record 30 of Set 5 | aberdeen
# Processing Record 31 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 32 of Set 5 | port hedland
# Processing Record 33 of Set 5 | tutoia
# Processing Record 34 of Set 5 | port lincoln
# Processing Record 35 of Set 5 | touros
# Processing Record 36 of Set 5 | flinders
# Processing Record 37 of Set 5 | itape
# Processing Record 38 of Set 5 | ostrovnoy
# Processing Record 39 of Set 5 | sao filipe
# Processing Record 40 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 5 | guerrero negro
# Processing Record 42 of Set 5 | praia da vitoria
# Processing Record 43 of Set 5 | bloomingdale
# Processing Record 44 of Set 5 | new norfolk
# Processing Record 45 of Set 5 | sakakah
# Processing Record 46 of Set 5 | shache
# Processing Record 47 of Set 5 | puerto leguizamo
# Processing Record 48 of Set 5 | chon daen
# Processing Record 49 of Set 5 | jining
# Processing Record 50 of Set 5 | cap malheureux
# Processing Record 1 of Set 6 | seymchan
# Processing Record 2 of Set 6 | kefamenanu
# Processing Record 3 of Set 6 | faanui
# Processing Record 4 of Set 6 | san cosme y damian
# Processing Record 5 of Set 6 | kamyaran
# Processing Record 6 of Set 6 | bubaque
# Processing Record 7 of Set 6 | vao
# Processing Record 8 of Set 6 | seredka
# Processing Record 9 of Set 6 | morondava
# Processing Record 10 of Set 6 | cascais
# Processing Record 11 of Set 6 | storslett
# Processing Record 12 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 6 | trelew
# Processing Record 14 of Set 6 | souillac
# Processing Record 15 of Set 6 | chitipa
# Processing Record 16 of Set 6 | deep river
# Processing Record 17 of Set 6 | ugoofaaru
# Processing Record 18 of Set 6 | polson
# Processing Record 19 of Set 6 | airai
# Processing Record 20 of Set 6 | buala
# Processing Record 21 of Set 6 | nerchinskiy zavod
# Processing Record 22 of Set 6 | bathsheba
# Processing Record 23 of Set 6 | maceio
# Processing Record 24 of Set 6 | betare oya
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | iquique
# Processing Record 27 of Set 6 | paraiso
# Processing Record 28 of Set 6 | hay river
# Processing Record 29 of Set 6 | honiara
# Processing Record 30 of Set 6 | kichmengskiy gorodok
# Processing Record 31 of Set 6 | paso de carrasco
# Processing Record 32 of Set 6 | yerbogachen
# Processing Record 33 of Set 6 | dangriga
# Processing Record 34 of Set 6 | pimentel
# Processing Record 35 of Set 6 | yarada
# Processing Record 36 of Set 6 | songea
# Processing Record 37 of Set 6 | xichang
# Processing Record 38 of Set 6 | lalomanu
# City not found. Skipping...
# Processing Record 39 of Set 6 | hukuntsi
# Processing Record 40 of Set 6 | lagoa
# Processing Record 41 of Set 6 | saurimo
# Processing Record 42 of Set 6 | pembroke
# Processing Record 43 of Set 6 | tibu
# Processing Record 44 of Set 6 | solnechnyy
# Processing Record 45 of Set 6 | itarema
# Processing Record 46 of Set 6 | mackenzie
# Processing Record 47 of Set 6 | butaritari
# Processing Record 48 of Set 6 | kaeo
# Processing Record 49 of Set 6 | anadyr
# Processing Record 50 of Set 6 | morristown
# Processing Record 1 of Set 7 | henties bay
# Processing Record 2 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 7 | sinnamary
# Processing Record 4 of Set 7 | coquimbo
# Processing Record 5 of Set 7 | anan
# Processing Record 6 of Set 7 | castro
# Processing Record 7 of Set 7 | uk
# City not found. Skipping...
# Processing Record 8 of Set 7 | turukhansk
# Processing Record 9 of Set 7 | khammam
# Processing Record 10 of Set 7 | khash
# Processing Record 11 of Set 7 | alyangula
# Processing Record 12 of Set 7 | pevek
# Processing Record 13 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 7 | oussouye
# Processing Record 16 of Set 7 | pagouria
# Processing Record 17 of Set 7 | kungurtug
# Processing Record 18 of Set 7 | marquette
# Processing Record 19 of Set 7 | port moresby
# Processing Record 20 of Set 7 | khatanga
# Processing Record 21 of Set 7 | dir
# Processing Record 22 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 7 | chuy
# Processing Record 24 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 7 | sola
# Processing Record 27 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 28 of Set 7 | acapulco
# Processing Record 29 of Set 7 | padang
# Processing Record 30 of Set 7 | kavieng
# Processing Record 31 of Set 7 | nouadhibou
# Processing Record 32 of Set 7 | chimoio
# Processing Record 33 of Set 7 | tuatapere
# Processing Record 34 of Set 7 | hamilton
# Processing Record 35 of Set 7 | wanning
# Processing Record 36 of Set 7 | cestas
# Processing Record 37 of Set 7 | jaciara
# Processing Record 38 of Set 7 | nogliki
# Processing Record 39 of Set 7 | kavaratti
# Processing Record 40 of Set 7 | ampanihy
# Processing Record 41 of Set 7 | soyo
# Processing Record 42 of Set 7 | meulaboh
# Processing Record 43 of Set 7 | kadiri
# Processing Record 44 of Set 7 | khilok
# Processing Record 45 of Set 7 | omsukchan
# Processing Record 46 of Set 7 | ancud
# Processing Record 47 of Set 7 | azrow
# City not found. Skipping...
# Processing Record 48 of Set 7 | yulara
# Processing Record 49 of Set 7 | tolaga bay
# Processing Record 50 of Set 7 | lienz
# Processing Record 1 of Set 8 | west bay
# Processing Record 2 of Set 8 | beni
# Processing Record 3 of Set 8 | kaffrine
# Processing Record 4 of Set 8 | kati
# Processing Record 5 of Set 8 | gaoua
# Processing Record 6 of Set 8 | yar-sale
# Processing Record 7 of Set 8 | miraflores
# Processing Record 8 of Set 8 | aykhal
# Processing Record 9 of Set 8 | ulladulla
# Processing Record 10 of Set 8 | deputatskiy
# Processing Record 11 of Set 8 | kibungo
# Processing Record 12 of Set 8 | badiraguato
# Processing Record 13 of Set 8 | aitape
# Processing Record 14 of Set 8 | caravelas
# Processing Record 15 of Set 8 | monrovia
# Processing Record 16 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 17 of Set 8 | kabanjahe
# Processing Record 18 of Set 8 | onega
# Processing Record 19 of Set 8 | taltal
# Processing Record 20 of Set 8 | turochak
# Processing Record 21 of Set 8 | kailua
# Processing Record 22 of Set 8 | dhana
# Processing Record 23 of Set 8 | umm kaddadah
# Processing Record 24 of Set 8 | isfana
# Processing Record 25 of Set 8 | skovorodino
# Processing Record 26 of Set 8 | beloha
# Processing Record 27 of Set 8 | vila velha
# Processing Record 28 of Set 8 | christchurch
# Processing Record 29 of Set 8 | qasigiannguit
# Processing Record 30 of Set 8 | kruisfontein
# Processing Record 31 of Set 8 | rathdrum
# Processing Record 32 of Set 8 | oktyabrskiy
# Processing Record 33 of Set 8 | irece
# Processing Record 34 of Set 8 | necochea
# Processing Record 35 of Set 8 | bambanglipuro
# Processing Record 36 of Set 8 | smidovich
# Processing Record 37 of Set 8 | northam
# Processing Record 38 of Set 8 | guaruja
# Processing Record 39 of Set 8 | hun
# Processing Record 40 of Set 8 | george
# Processing Record 41 of Set 8 | kiseljak
# Processing Record 42 of Set 8 | mineiros
# Processing Record 43 of Set 8 | astana
# Processing Record 44 of Set 8 | great yarmouth
# Processing Record 45 of Set 8 | vostok
# Processing Record 46 of Set 8 | otavi
# Processing Record 47 of Set 8 | havelock
# Processing Record 48 of Set 8 | bam
# Processing Record 49 of Set 8 | fort nelson
# Processing Record 50 of Set 8 | amalapuram
# Processing Record 1 of Set 9 | neya
# Processing Record 2 of Set 9 | sakata
# Processing Record 3 of Set 9 | quatre cocos
# Processing Record 4 of Set 9 | sedalia
# Processing Record 5 of Set 9 | harper
# Processing Record 6 of Set 9 | saint-leu
# Processing Record 7 of Set 9 | zhezkazgan
# Processing Record 8 of Set 9 | minna
# Processing Record 9 of Set 9 | chontalpa
# Processing Record 10 of Set 9 | sedniv
# Processing Record 11 of Set 9 | vanimo
# Processing Record 12 of Set 9 | codrington
# Processing Record 13 of Set 9 | anito
# Processing Record 14 of Set 9 | chambas
# Processing Record 15 of Set 9 | tiarei
# Processing Record 16 of Set 9 | zaranj
# Processing Record 17 of Set 9 | luanda
# Processing Record 18 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 9 | naples
# Processing Record 20 of Set 9 | tigre
# Processing Record 21 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 22 of Set 9 | cabo san lucas
# Processing Record 23 of Set 9 | jizan
# Processing Record 24 of Set 9 | la asuncion
# Processing Record 25 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 9 | bandarbeyla
# Processing Record 27 of Set 9 | vetluga
# Processing Record 28 of Set 9 | gamba
# Processing Record 29 of Set 9 | milverton
# Processing Record 30 of Set 9 | kloulklubed
# Processing Record 31 of Set 9 | los llanos de aridane
# Processing Record 32 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 9 | bambous virieux
# Processing Record 34 of Set 9 | mayo
# Processing Record 35 of Set 9 | nemuro
# Processing Record 36 of Set 9 | lashio
# Processing Record 37 of Set 9 | mogadishu
# Processing Record 38 of Set 9 | dabat
# Processing Record 39 of Set 9 | issenye
# Processing Record 40 of Set 9 | leh
# Processing Record 41 of Set 9 | milyutinskaya
# Processing Record 42 of Set 9 | leningradskiy
# Processing Record 43 of Set 9 | saint-joseph
# Processing Record 44 of Set 9 | rio gallegos
# Processing Record 45 of Set 9 | xinzhi
# Processing Record 46 of Set 9 | lipari
# Processing Record 47 of Set 9 | bac lieu
# Processing Record 48 of Set 9 | tautira
# Processing Record 49 of Set 9 | gornopravdinsk
# Processing Record 50 of Set 9 | brewster
# Processing Record 1 of Set 10 | adrar
# Processing Record 2 of Set 10 | burnie
# Processing Record 3 of Set 10 | ocos
# Processing Record 4 of Set 10 | ekibastuz
# Processing Record 5 of Set 10 | novodugino
# Processing Record 6 of Set 10 | khandyga
# Processing Record 7 of Set 10 | marienburg
# Processing Record 8 of Set 10 | singaraja
# Processing Record 9 of Set 10 | belinskiy
# Processing Record 10 of Set 10 | soe
# Processing Record 11 of Set 10 | road town
# Processing Record 12 of Set 10 | tanout
# Processing Record 13 of Set 10 | kurilsk
# Processing Record 14 of Set 10 | suba
# Processing Record 15 of Set 10 | conceicao do araguaia
# Processing Record 16 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 17 of Set 10 | kaoma
# Processing Record 18 of Set 10 | port-gentil
# Processing Record 19 of Set 10 | bulgan
# Processing Record 20 of Set 10 | pacifica
# Processing Record 21 of Set 10 | jinchang
# Processing Record 22 of Set 10 | hirara
# Processing Record 23 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 10 | coihaique
# Processing Record 25 of Set 10 | sa kaeo
# Processing Record 26 of Set 10 | dawson creek
# Processing Record 27 of Set 10 | tsaratanana
# Processing Record 28 of Set 10 | kommunisticheskiy
# Processing Record 29 of Set 10 | sinor
# Processing Record 30 of Set 10 | tiznit
# Processing Record 31 of Set 10 | lethem
# Processing Record 32 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 33 of Set 10 | mount isa
# Processing Record 34 of Set 10 | keti bandar
# Processing Record 35 of Set 10 | andrieseni
# Processing Record 36 of Set 10 | kars
# Processing Record 37 of Set 10 | wilmington
# Processing Record 38 of Set 10 | krasnoselkup
# Processing Record 39 of Set 10 | qaqortoq
# Processing Record 40 of Set 10 | geraldton
# Processing Record 41 of Set 10 | jalu
# Processing Record 42 of Set 10 | muros
# Processing Record 43 of Set 10 | sumkino
# Processing Record 44 of Set 10 | jati
# Processing Record 45 of Set 10 | qandala
# Processing Record 46 of Set 10 | buraydah
# Processing Record 47 of Set 10 | marfino
# Processing Record 48 of Set 10 | togur
# Processing Record 49 of Set 10 | yarim
# Processing Record 50 of Set 10 | dzerzhinsk
# Processing Record 1 of Set 11 | ende
# Processing Record 2 of Set 11 | lompoc
# Processing Record 3 of Set 11 | kousseri
# Processing Record 4 of Set 11 | roma
# Processing Record 5 of Set 11 | marawi
# Processing Record 6 of Set 11 | hailar
# Processing Record 7 of Set 11 | grand gaube
# Processing Record 8 of Set 11 | safranbolu
# Processing Record 9 of Set 11 | balakliya
# Processing Record 10 of Set 11 | villanueva de la serena
# Processing Record 11 of Set 11 | north bend
# Processing Record 12 of Set 11 | noumea
# Processing Record 13 of Set 11 | gorontalo
# Processing Record 14 of Set 11 | pokrovka
# Processing Record 15 of Set 11 | fort payne
# Processing Record 16 of Set 11 | key largo
# Processing Record 17 of Set 11 | moletai
# Processing Record 18 of Set 11 | mulatupo
# Processing Record 19 of Set 11 | santa cruz
# Processing Record 20 of Set 11 | half moon bay
# Processing Record 21 of Set 11 | saryozek
# Processing Record 22 of Set 11 | sangar
# Processing Record 23 of Set 11 | goias
# Processing Record 24 of Set 11 | lazaro cardenas
# Processing Record 25 of Set 11 | luderitz
# Processing Record 26 of Set 11 | rochester
# Processing Record 27 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 11 | lakes entrance
# Processing Record 29 of Set 11 | desna
# Processing Record 30 of Set 11 | okhotsk
# Processing Record 31 of Set 11 | castelfiorentino
# Processing Record 32 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 33 of Set 11 | belmonte
# Processing Record 34 of Set 11 | port augusta
# Processing Record 35 of Set 11 | vigrestad
# Processing Record 36 of Set 11 | camopi
# Processing Record 37 of Set 11 | diffa
# Processing Record 38 of Set 11 | yima
# Processing Record 39 of Set 11 | el rosario
# Processing Record 40 of Set 11 | mapastepec
# Processing Record 41 of Set 11 | arequipa
# Processing Record 42 of Set 11 | clarence town
# Processing Record 43 of Set 11 | calabozo
# Processing Record 44 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 45 of Set 11 | qabis
# City not found. Skipping...
# Processing Record 46 of Set 11 | manggar
# Processing Record 47 of Set 11 | teguldet
# Processing Record 48 of Set 11 | bushehr
# Processing Record 49 of Set 11 | porto novo
# Processing Record 50 of Set 11 | opuwo
# Processing Record 1 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 12 | broome
# Processing Record 3 of Set 12 | gaimersheim
# Processing Record 4 of Set 12 | sioux lookout
# Processing Record 5 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 12 | clinton
# Processing Record 7 of Set 12 | coahuayana
# Processing Record 8 of Set 12 | strezhevoy
# Processing Record 9 of Set 12 | svobodnyy
# Processing Record 10 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 12 | ballina
# Processing Record 12 of Set 12 | sansai
# City not found. Skipping...
# Processing Record 13 of Set 12 | madang
# Processing Record 14 of Set 12 | ludvika
# Processing Record 15 of Set 12 | iberia
# Processing Record 16 of Set 12 | nizhneudinsk
# Processing Record 17 of Set 12 | voh
# Processing Record 18 of Set 12 | saint-francois
# Processing Record 19 of Set 12 | whitehorse
# Processing Record 20 of Set 12 | dingle
# Processing Record 21 of Set 12 | maur
# Processing Record 22 of Set 12 | channel-port aux basques
# Processing Record 23 of Set 12 | vung tau
# Processing Record 24 of Set 12 | canico
# Processing Record 25 of Set 12 | la cruz
# Processing Record 26 of Set 12 | concepcion del uruguay
# Processing Record 27 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 12 | tucuman
# Processing Record 29 of Set 12 | shitkino
# Processing Record 30 of Set 12 | sundarnagar
# Processing Record 31 of Set 12 | uvalde
# Processing Record 32 of Set 12 | nokaneng
# Processing Record 33 of Set 12 | itarantim
# Processing Record 34 of Set 12 | gigmoto
# Processing Record 35 of Set 12 | weligama
# Processing Record 36 of Set 12 | redmond
# Processing Record 37 of Set 12 | puerto penasco
# Processing Record 38 of Set 12 | praia
# Processing Record 39 of Set 12 | russell
# Processing Record 40 of Set 12 | atmakur
# Processing Record 41 of Set 12 | calama
# Processing Record 42 of Set 12 | bramming
# Processing Record 43 of Set 12 | murray bridge
# Processing Record 44 of Set 12 | inuvik
# Processing Record 45 of Set 12 | bairiki
# Processing Record 46 of Set 12 | verkhoyansk
# Processing Record 47 of Set 12 | kabo
# Processing Record 48 of Set 12 | itaituba
# Processing Record 49 of Set 12 | ilka
# City not found. Skipping...
# Processing Record 50 of Set 12 | sabang
# Processing Record 1 of Set 13 | nago
# Processing Record 2 of Set 13 | shizilu
# Processing Record 3 of Set 13 | fortuna
# Processing Record 4 of Set 13 | paamiut
# Processing Record 5 of Set 13 | sorland
# Processing Record 6 of Set 13 | nicosia
# Processing Record 7 of Set 13 | ulaangom
# Processing Record 8 of Set 13 | chenzhou
# Processing Record 9 of Set 13 | nantucket
# Processing Record 10 of Set 13 | labuan
# Processing Record 11 of Set 13 | adana
# Processing Record 12 of Set 13 | nalut
# Processing Record 13 of Set 13 | bayji
# Processing Record 14 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 15 of Set 13 | troitsko-pechorsk
# Processing Record 16 of Set 13 | pachino
# Processing Record 17 of Set 13 | manicore
# Processing Record 18 of Set 13 | emmett
# Processing Record 19 of Set 13 | araouane
# Processing Record 20 of Set 13 | snezhnogorsk
# Processing Record 21 of Set 13 | verkhniye sergi
# Processing Record 22 of Set 13 | korla
# Processing Record 23 of Set 13 | orocue
# Processing Record 24 of Set 13 | talara
# Processing Record 25 of Set 13 | tura
# Processing Record 26 of Set 13 | marsa matruh
# Processing Record 27 of Set 13 | asyut
# Processing Record 28 of Set 13 | jumla
# Processing Record 29 of Set 13 | batagay
# Processing Record 30 of Set 13 | yarkovo
# Processing Record 31 of Set 13 | lasa
# Processing Record 32 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 33 of Set 13 | kiunga
# Processing Record 34 of Set 13 | nacajuca
# Processing Record 35 of Set 13 | faya
# Processing Record 36 of Set 13 | vastervik
# City not found. Skipping...
# Processing Record 37 of Set 13 | yambio
# Processing Record 38 of Set 13 | monaco-ville
# Processing Record 39 of Set 13 | sitka
# Processing Record 40 of Set 13 | suining
# Processing Record 41 of Set 13 | blagoyevo
# Processing Record 42 of Set 13 | batagay-alyta
# Processing Record 43 of Set 13 | lakatoro
# Processing Record 44 of Set 13 | ilulissat
# Processing Record 45 of Set 13 | akyab
# Processing Record 46 of Set 13 | shelburne
# Processing Record 47 of Set 13 | suez
# Processing Record 48 of Set 13 | lubango
# Processing Record 49 of Set 13 | rio grande
# Processing Record 50 of Set 13 | saint-paul
# Processing Record 1 of Set 14 | biak
# Processing Record 2 of Set 14 | port macquarie
# Processing Record 3 of Set 14 | yagodnoye
# Processing Record 4 of Set 14 | mount gambier
# Processing Record 5 of Set 14 | kasongo-lunda
# Processing Record 6 of Set 14 | kuruman
# Processing Record 7 of Set 14 | koulikoro
# Processing Record 8 of Set 14 | asmar
# Processing Record 9 of Set 14 | nouakchott
# Processing Record 10 of Set 14 | ambilobe
# Processing Record 11 of Set 14 | erie
# Processing Record 12 of Set 14 | beisfjord
# Processing Record 13 of Set 14 | belawan
# Processing Record 14 of Set 14 | lindsay
# Processing Record 15 of Set 14 | pemangkat
# Processing Record 16 of Set 14 | micheweni
# Processing Record 17 of Set 14 | kupang
# Processing Record 18 of Set 14 | wum
# Processing Record 19 of Set 14 | oistins
# Processing Record 20 of Set 14 | naberera
# Processing Record 21 of Set 14 | brae
# Processing Record 22 of Set 14 | lagos
# Processing Record 23 of Set 14 | deggendorf
# Processing Record 24 of Set 14 | antakya
# Processing Record 25 of Set 14 | crnomelj
# Processing Record 26 of Set 14 | megion
# Processing Record 27 of Set 14 | najran
# Processing Record 28 of Set 14 | rocha
# Processing Record 29 of Set 14 | weihe
# Processing Record 30 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 14 | bengkulu
# Processing Record 32 of Set 14 | pundaguitan
# Processing Record 33 of Set 14 | launceston
# Processing Record 34 of Set 14 | bazarnyye mataki
# Processing Record 35 of Set 14 | gap
# Processing Record 36 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 37 of Set 14 | verkh-chebula
# Processing Record 38 of Set 14 | poronaysk
# Processing Record 39 of Set 14 | kattivakkam
# Processing Record 40 of Set 14 | blackwater
# Processing Record 41 of Set 14 | aswan
# Processing Record 42 of Set 14 | goure
# Processing Record 43 of Set 14 | iskateley
# Processing Record 44 of Set 14 | radomsko
# Processing Record 45 of Set 14 | cartagena del chaira
# Processing Record 46 of Set 14 | alofi
# Processing Record 47 of Set 14 | hobyo
# Processing Record 48 of Set 14 | hoima
# Processing Record 49 of Set 14 | mbarara
# Processing Record 50 of Set 14 | ust-maya
# Processing Record 1 of Set 15 | moroni
# Processing Record 2 of Set 15 | nueva loja
# Processing Record 3 of Set 15 | nata
# Processing Record 4 of Set 15 | hovd
# Processing Record 5 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 6 of Set 15 | bunia
# Processing Record 7 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 8 of Set 15 | carballo
# Processing Record 9 of Set 15 | kapuskasing
# Processing Record 10 of Set 15 | bristol
# Processing Record 11 of Set 15 | arlit
# Processing Record 12 of Set 15 | richards bay
# Processing Record 13 of Set 15 | mudgal
# Processing Record 14 of Set 15 | shenjiamen
# Processing Record 15 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 16 of Set 15 | rovaniemi
# Processing Record 17 of Set 15 | tabuk
# Processing Record 18 of Set 15 | beringovskiy
# Processing Record 19 of Set 15 | las choapas
# Processing Record 20 of Set 15 | toamasina
# Processing Record 21 of Set 15 | suhbaatar
# Processing Record 22 of Set 15 | nador
# Processing Record 23 of Set 15 | westport
# Processing Record 24 of Set 15 | olafsvik
# Processing Record 25 of Set 15 | bolnisi
# Processing Record 26 of Set 15 | mangrol
# Processing Record 27 of Set 15 | bhadra
# Processing Record 28 of Set 15 | port hardy
# Processing Record 29 of Set 15 | almaznyy
# Processing Record 30 of Set 15 | san juan
# Processing Record 31 of Set 15 | inirida
# Processing Record 32 of Set 15 | vestmanna
# Processing Record 33 of Set 15 | arroyo
# Processing Record 34 of Set 15 | mpanda
# Processing Record 35 of Set 15 | ikwiriri
# Processing Record 36 of Set 15 | ibra
# Processing Record 37 of Set 15 | kondinskoye
# Processing Record 38 of Set 15 | dumas
# Processing Record 39 of Set 15 | khani
# Processing Record 40 of Set 15 | taian
# Processing Record 41 of Set 15 | tupelo
# Processing Record 42 of Set 15 | maningrida
# Processing Record 43 of Set 15 | ponta delgada
# Processing Record 44 of Set 15 | gubkinskiy
# Processing Record 45 of Set 15 | mackay
# Processing Record 46 of Set 15 | eureka
# Processing Record 47 of Set 15 | baruun-urt
# Processing Record 48 of Set 15 | khambhaliya
# Processing Record 49 of Set 15 | ekuvukeni
# Processing Record 50 of Set 15 | owensboro
# Processing Record 1 of Set 16 | zaraza
# Processing Record 2 of Set 16 | rudbar
# Processing Record 3 of Set 16 | serendah
# Processing Record 4 of Set 16 | dhidhdhoo
# Processing Record 5 of Set 16 | portland
# Processing Record 6 of Set 16 | pacific grove
# Processing Record 7 of Set 16 | voyvozh
# Processing Record 8 of Set 16 | qidong
# Processing Record 9 of Set 16 | udachnyy
# Processing Record 10 of Set 16 | kegayli
# City not found. Skipping...
# Processing Record 11 of Set 16 | atar
# Processing Record 12 of Set 16 | sibolga
# Processing Record 13 of Set 16 | kushmurun
# Processing Record 14 of Set 16 | tari
# Processing Record 15 of Set 16 | groningen
# Processing Record 16 of Set 16 | shimoda
# Processing Record 17 of Set 16 | ano mera
# Processing Record 18 of Set 16 | kulu
# Processing Record 19 of Set 16 | xiaoweizhai
# Processing Record 20 of Set 16 | olean
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(10)
# Out:
#                 City      Description    Lat     Lng  Max Temp  Humidity  \
# 0          Busselton       light rain -33.65  115.33     55.99        85
# 1  Sao Joao Da Barra  overcast clouds -21.64  -41.05     73.87        95
# 2         Lavrentiya  overcast clouds  65.58 -171.00     27.90        97
# 3           Manthani        clear sky  18.65   79.67     77.67        43
# 4      Marsh Harbour  overcast clouds  26.54  -77.06     79.07        82
# 5         Georgetown       light rain   5.41  100.34     84.20        74
# 6           Rosarito       few clouds  32.33 -117.03     57.00        66
# 7               Tula        clear sky  54.20   37.61     33.75        89
# 8             Barrow  overcast clouds  71.29 -156.79     15.80        78
# 9            Awjilah        clear sky  29.11   21.29     58.69        69
#
#    Cloudiness  Wind Speed Country
# 0         100       11.01      AU
# 1          99        2.95      BR
# 2          93        9.42      RU
# 3           0        6.20      IN
# 4         100       28.95      BS
# 5          20        3.36      MY
# 6          20       13.87      MX
# 7           0        7.90      RU
# 8          90       25.28      US
# 9           0        7.23      LY

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description" ]

# %%
ordered_city_data_df = city_data_df[new_column_order]

# %%
ordered_city_data_df = ordered_city_data_df.rename(columns={'Description': 'Current Description'})

# %%
ordered_city_data_df.head(10)
# Out:
#                 City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Busselton      AU -33.65  115.33     55.99        85         100
# 1  Sao Joao Da Barra      BR -21.64  -41.05     73.87        95          99
# 2         Lavrentiya      RU  65.58 -171.00     27.90        97          93
# 3           Manthani      IN  18.65   79.67     77.67        43           0
# 4      Marsh Harbour      BS  26.54  -77.06     79.07        82         100
# 5         Georgetown      MY   5.41  100.34     84.20        74          20
# 6           Rosarito      MX  32.33 -117.03     57.00        66          20
# 7               Tula      RU  54.20   37.61     33.75        89           0
# 8             Barrow      US  71.29 -156.79     15.80        78          90
# 9            Awjilah      LY  29.11   21.29     58.69        69           0
#
#    Wind Speed Current Description
# 0       11.01          light rain
# 1        2.95     overcast clouds
# 2        9.42     overcast clouds
# 3        6.20           clear sky
# 4       28.95     overcast clouds
# 5        3.36          light rain
# 6       13.87          few clouds
# 7        7.90           clear sky
# 8       25.28     overcast clouds
# 9        7.23           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
ordered_city_data_df.to_csv(output_data_file, index_label="City_ID")
